# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyasinha518/FSP-CSE/blob/main/Artfical_Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/ML Folder/Churn_Modelling (2).csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311        NaN          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888        NaN          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # New section

# %%
x=df.iloc[:,3:-1].values
x
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]], dtype=object)

# %%
from sklearn.preprocessing  import LabelEncoder
en1=LabelEncoder()
x[:,1]=en1.fit_transform(x[:,1])
en2=LabelEncoder()
x[:,2]=en2.fit_transform(x[:,2])
x
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.32622142, -0.90188624, -1.09598752, ...,  0.64609167,
#          0.97024255,  0.02188649],
#        [-0.44003595,  1.51506738, -1.09598752, ..., -1.54776799,
#          0.97024255,  0.21653375],
#        [-1.53679418, -0.90188624, -1.09598752, ...,  0.64609167,
#         -1.03067011,  0.2406869 ],
#        ...,
#        [ 0.60498839, -0.90188624, -1.09598752, ..., -1.54776799,
#          0.97024255, -1.00864308],
#        [ 1.25683526,  0.30659057,  0.91241915, ...,  0.64609167,
#         -1.03067011, -0.12523071],
#        [ 1.46377078, -0.90188624, -1.09598752, ...,  0.64609167,
#         -1.03067011, -1.07636976]])

# %%
y=df.iloc[:,-1].values
y
# Out:
# array([1, 0, 1, ..., 1, 1, 0])

# %%
from sklearn .model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
x_train
# Out:
# array([[-0.23310044,  0.30659057,  0.91241915, ..., -1.54776799,
#          0.97024255,  0.42879259],
#        [-0.25379399, -0.90188624, -1.09598752, ..., -1.54776799,
#         -1.03067011, -1.02569751],
#        [-0.39864885,  0.30659057, -1.09598752, ...,  0.64609167,
#          0.97024255, -0.94491882],
#        ...,
#        [ 0.22215769, -0.90188624, -1.09598752, ...,  0.64609167,
#          0.97024255, -0.14019969],
#        [ 0.12903671, -0.90188624, -1.09598752, ...,  0.64609167,
#          0.97024255,  0.01875682],
#        [ 1.16371428,  0.30659057,  0.91241915, ...,  0.64609167,
#         -1.03067011, -1.15858217]])

# %%
x_train.shape
# Out:
# (8000, 10)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
model=Sequential()
model.add(Dense(units=64,activation='relu',input_dim=10))
model.add(Dense(units=32,activation='relu'))
model.add(Dense(units=16,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_5 (Dense)                 │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,329 (13.00 KB)
#  Trainable params: 3,329 (13.00 KB)
# ...

# %%
model.fit(x_train,y_train,epochs=100,batch_size=32,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7469 - loss: 0.5302 - val_accuracy: 0.8325 - val_loss: 0.4078
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8343 - loss: 0.3957 - val_accuracy: 0.8530 - val_loss: 0.3574
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8587 - loss: 0.3476 - val_accuracy: 0.8550 - val_loss: 0.3483
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8593 - loss: 0.3474 - val_accuracy: 0.8520 - val_loss: 0.3473
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8660 - loss: 0.3337 - val_accuracy: 0.8600 - val_loss: 0.3389
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8650 - loss: 0.3286 - val_accuracy: 0.8570 - val_loss: 0.3426
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8595 - loss: 0.3350 - val_accuracy: 0.8540 - val_loss: 0.3364
# Epoch 8/100
# ...

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[1.8536225e-03],
#        [3.4358621e-02],
#        [5.4649560e-04],
#        ...,
#        [7.9332709e-09],
#        [4.1491040e-03],
#        [9.5046258e-01]], dtype=float32)

# %%
y_pred=model.predict(x_test)
y_pred=y_pred>.5
y_pred
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [ True]])

# %%
y_pred=model.predict(x_test)
y_pred=(y_pred>.5).astype("int32")
y_pred
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [1]], dtype=int32)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
print("Accuracy=",accuracy_score(y_test,y_pred))
print("Precission=",precision_score(y_test,y_pred))
print("Accuracy=",recall_score(y_test,y_pred))
# Out:
# [[1479  106]
#  [ 216  199]]
# Accuracy= 0.839
# Precission= 0.6524590163934426
# Accuracy= 0.4795180722891566
