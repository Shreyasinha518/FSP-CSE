# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreyasinha518/FSP-CSE/blob/main/panda_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
s1=pd.Series([11,22,33,44,55],index=['a','b','c','d','e'])
print(s1)
# Out:
# a    11
# b    22
# c    33
# d    44
# e    55
# dtype: int64

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
d={"id":120,"name":"Shreya","email":"Shreyasinhamisti999@gmail.com"}
s2=pd.Series(d);
print(s2)
# Out:
# id                                 120
# name                            Shreya
# email    Shreyasinhamisti999@gmail.com
# dtype: object

# %%
d1={
    "names":["Raj","Avik","Vipin","Kamal"],
   "phys":[89,88,87,98],
    "chem":[89,88,87,98],
       "maths":[89,88,87,98],
}
s3=pd.Series(d1)
print(s3)
# Out:
# names    [Raj, Avik, Vipin, Kamal]
# phys              [89, 88, 87, 98]
# chem              [89, 88, 87, 98]
# maths             [89, 88, 87, 98]
# dtype: object

# %%
df=pd.DataFrame(d1)
df
# Out:
#    names  phys  chem  maths
# 0    Raj    89    89     89
# 1   Avik    88    88     88
# 2  Vipin    87    87     87
# 3  Kamal    98    98     98

# %%
df2=pd.read_csv('/content/Income_data (1).csv')
df2
# Out:
#        GEOID       State   2005     2006   2007   2008   2009   2010   2011  \
# 0  04000US01     Alabama  37150  37952.0  42212  44476  39980  40933  42590
# 1  04000US02      Alaska  55891      NaN  62993  63989  61604  57848  57431
# 2  04000US04     Arizona  45245  46657.0  47215  46914  45739  46896  48621
# 3  04000US05    Arkansas  36658  37057.0  40795  39586  36538  38587  41302
# 4  04000US06  California  51755  55319.0  55734  57014  56134  54283  53367
#
#     2012   2013
# 0  43464  41381
# 1  63648  61137
# 2  47044  50602
# 3  39018  39919
# 4  57020  57528

# %%
df2=df2.set_index("State")
df2
# Out:
#                 GEOID   2005     2006   2007   2008   2009   2010   2011  \
# State
# Alabama     04000US01  37150  37952.0  42212  44476  39980  40933  42590
# Alaska      04000US02  55891      NaN  62993  63989  61604  57848  57431
# Arizona     04000US04  45245  46657.0  47215  46914  45739  46896  48621
# Arkansas    04000US05  36658  37057.0  40795  39586  36538  38587  41302
# California  04000US06  51755  55319.0  55734  57014  56134  54283  53367
#
#              2012   2013
# State
# Alabama     43464  41381
# Alaska      63648  61137
# Arizona     47044  50602
# Arkansas    39018  39919
# California  57020  57528

# %%
df3=df2.loc["Alabama":"Arizona","2005":"2007"]
df3
# Out:
#           2005     2006   2007
# State
# Alabama  37150  37952.0  42212
# Alaska   55891      NaN  62993
# Arizona  45245  46657.0  47215

# %%
df4=df2.iloc[0:3,1:4]
df4
# Out:
#           2005     2006   2007
# State
# Alabama  37150  37952.0  42212
# Alaska   55891      NaN  62993
# Arizona  45245  46657.0  47215

# %%
df4.sum(axis=1)
# Out:
# State
# Alabama    117314.0
# Alaska     118884.0
# Arizona    139117.0
# dtype: float64

# %%
df5=df2.loc[["Alabama","Arizona","California"],["2007","2009"]]
df5
# Out:
#              2007   2009
# State
# Alabama     42212  39980
# Arizona     47215  45739
# California  55734  56134

# %%
df6=df2.loc["California","2005":]
df6
# Out:
# 2005      51755
# 2006    55319.0
# 2007      55734
# 2008      57014
# 2009      56134
# 2010      54283
# 2011      53367
# 2012      57020
# 2013      57528
# Name: California, dtype: object

# %%
s=df6.sum()
print(s)
# Out:
# 498154.0

# %%
df7=df2.loc["California","2013"]
print(df7)
# Out:
# 57528
